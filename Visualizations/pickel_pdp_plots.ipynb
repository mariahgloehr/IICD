# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D   # noqa: F401 (needed for 3D)
from sklearn.tree import DecisionTreeRegressor

# %%
# !pip install scikit-learn==1.4.0
# Out:
# Collecting scikit-learn==1.4.0
#   Downloading scikit_learn-1.4.0-1-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting numpy<2.0,>=1.19.5 (from scikit-learn==1.4.0)
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: scipy>=1.6.0 in /Users/mariahloehr/IICD/IICD/sklearn-env/lib/python3.12/site-packages (from scikit-learn==1.4.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mariahloehr/IICD/IICD/sklearn-env/lib/python3.12/site-packages (from scikit-learn==1.4.0) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mariahloehr/IICD/IICD/sklearn-env/lib/python3.12/site-packages (from scikit-learn==1.4.0) (3.6.0)
# Downloading scikit_learn-1.4.0-1-cp312-cp312-macosx_12_0_arm64.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 12.4 MB/s  0:00:00 eta 0:00:01
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 13.8 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
#   Attempting uninstall: scikit-learn━━━━━━━━━━━━ 0/2 [numpy]
#     Found existing installation: scikit-learn 1.7.032m0/2 [numpy]
#     Uninstalling scikit-learn-1.7.0:m╺━━━━━━━━━━━━━━━━━━━ 1/2 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.7.0━━━━━━━━━━━━━ 1/2 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [scikit-learn] [scikit-learn]
# Successfully installed numpy-1.26.4 scikit-learn-1.4.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pickle, joblib

with open("/Users/mariahloehr/IICD/IICD/Benchmarks/ensemble_comp.pkl", "rb") as f:
    mp_ensemble = pickle.load(f)

# Re-save safely
joblib.dump(mp_ensemble, "/Users/mariahloehr/IICD/IICD/Benchmarks/ensemble_comp_v140.joblib")

print("Model re-saved successfully!")
# Out:
# Model re-saved successfully!

# %%
# !pip install --upgrade scikit-learn==1.7.0
# Out:
# Collecting scikit-learn==1.7.0
#   Using cached scikit_learn-1.7.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.22.0 in /Users/mariahloehr/IICD/IICD/sklearn-env/lib/python3.12/site-packages (from scikit-learn==1.7.0) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /Users/mariahloehr/IICD/IICD/sklearn-env/lib/python3.12/site-packages (from scikit-learn==1.7.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mariahloehr/IICD/IICD/sklearn-env/lib/python3.12/site-packages (from scikit-learn==1.7.0) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mariahloehr/IICD/IICD/sklearn-env/lib/python3.12/site-packages (from scikit-learn==1.7.0) (3.6.0)
# Using cached scikit_learn-1.7.0-cp312-cp312-macosx_12_0_arm64.whl (10.7 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.4.0
#     Uninstalling scikit-learn-1.4.0:
#       Successfully uninstalled scikit-learn-1.4.0
# Successfully installed scikit-learn-1.7.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
cell_cycle = pd.read_csv('/Users/mariahloehr/IICD/IICD/Data/cell_cycle_tidied.csv')

# %%
X = cell_cycle.drop(columns=['phase', 'age', 'PHATE_1', "PHATE_2"])  # Features

# %%
import pickle
with open("/Users/mariahloehr/IICD/IICD/Benchmarks/ensemble_comp.pkl", "rb") as f:
    mp_ensemble = pickle.load(f)

# Access the arrays by their keys
ensembles = mp_ensemble['ensemble']
predictions = mp_ensemble['predictions']
obs = mp_ensemble['mp_observations']
feats = mp_ensemble['mp_features']
