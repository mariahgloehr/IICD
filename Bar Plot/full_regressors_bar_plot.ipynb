# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.read_csv("/Users/mariahloehr/IICD/IICD/Bar Plot/regression_results.csv", index_col=0)
results_df = df[~df.index.to_series().str.contains("top 40")]

# %%
results_df
# Out:
#                  Overall        G0        G1        G2          M         S
# RF (full)       1.313224  1.451624  1.038931  1.408207   3.398515  1.393822
# Lasso (full)    2.007866  1.984856  1.506567  2.509816  10.996939  1.779818
# Ridge (full)    2.049552  2.118984  1.566594  2.518148  11.113529  1.748946
# XGBoost (full)  1.367819  1.490318  1.151884  1.385290   3.437150  1.443724
# MLP (full)      1.698152  1.694070  1.431431  1.973079   8.822113  1.463919

# %%
# Plot all bars
ax = results_df.plot(kind="bar", figsize=(12, 6), alpha=0.2)  # dim all bars

# Highlight "Overall" bars
overall_bars = ax.containers[0]  # "Overall" is usually the first container
for bar in overall_bars:
    bar.set_alpha(1.0)           # full opacity
    bar.set_color('tab:blue')    # standout color (optional)

# Style
plt.title("Model RMSE by Phase")
plt.ylabel("Accuracy")
plt.xticks(rotation=45, ha='right')
plt.legend(title="Phase")
plt.tight_layout()
plt.show()
